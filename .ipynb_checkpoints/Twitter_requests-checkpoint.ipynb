# %%
import requests
import os
import json

# %%
consumerKey = 'qFXNatPD5C2JFEQPlMTXFUr8x'
consumerSecret = 'VCTI9keIp1mqIKLwpuoApI7HSe5b0SpeUHvcQ676J3SOjuuISM'
accessToken = '1371497692069789697-0tx6gputswEwOMlwGfUy4VKBID5SCg'
accessTokenSecret = 'zSFpItEQObd4PBc7E0PFAvoJApglHJqbcT37TW928ji5P'
bearer_token = 'AAAAAAAAAAAAAAAAAAAAALrKOgEAAAAArFR4P0hcEIMgEKg1GkdQwgzVrpE%3D8htvsMPl4Bku7Hbl0jUSlzHjVNIwx8qABoB1l6Vf0sSD7Ki4hF'

# %%
def get_followers(id):
    return "https://api.twitter.com/2/users/{}/followers".format(id)

def get_following(id):
    return "https://api.twitter.com/2/users/{}/following".format(id)


def get_params():
    return {"user.fields": "created_at"}


def create_headers(bearer_token):
    headers = {"Authorization": "Bearer {}".format(bearer_token)}
    return headers


def connect_to_endpoint(url, headers, params):
    response = requests.request("GET", url, headers=headers, params=params)
    print(response.status_code)
    if response.status_code != 200:
        raise Exception(
            "Request returned an error: {} {}".format(
                response.status_code, response.text
            )
        )
    return response.json()


def main():
    user_id = 4289217222
    url = get_followers(user_id)
    headers = create_headers(bearer_token)
    params = get_params()
    json_response = connect_to_endpoint(url, headers, params)
    print(json.dumps(json_response, indent=4, sort_keys=True))

# %%
main()
# Out:
# 200
# {
#     "data": [
#         {
#             "created_at": "2010-06-16T10:39:44.000Z",
#             "id": "156229652",
#             "name": "Jon Moses",
#             "username": "jonmosesvocals"
#         },
#         {
#             "created_at": "2012-12-20T15:58:10.000Z",
#             "id": "1024517222",
#             "name": "\u2022\u25cf\u30c4 \u1d0b\u1d07\u1d07\u1d18\u1d00\u1d04\u029c\u0280\u026as \u30c4 \u25cf\u2022",
#             "username": "__keepachris__"
#         },
#         {
#             "created_at": "2019-09-13T05:07:09.000Z",
#             "id": "1172376123054813186",
#             "name": "Fade To Dark",
#             "username": "FadeToDarkMusic"
#         },
#         {
#             "created_at": "2013-01-09T22:39:12.000Z",
#             "id": "1075090154",
#             "name": "Abdulrahman Ha \ud80c\udc86",
#             "username": "AcDhme"
#         },
#         {
#             "created_at": "2020-06-07T02:10:13.000Z",
# ...

# %%
from TwitterAPI import TwitterAPI, TwitterOAuth, TwitterRequestError, TwitterConnectionError
from pprint import pprint

USER_ID = '4289217222' 
USER_FIELDS = 'location,profile_image_url,verified'


try:
    #o = TwitterOAuth.read_file()
    api = TwitterAPI(consumerKey, consumerSecret, accessToken, accessTokenSecret, api_version='2')

    # Get followers
    params = {'max_results':1000,'user.fields':USER_FIELDS}
    followers = api.request(f'users/:{USER_ID}/followers', params=params)
    for f in followers:
        print(f)

    # Get following
    #following = api.request(f'users/:{USER_ID}/following')
    #for f in following:
    #    print(f)   
        
except TwitterRequestError as e:
    print('Request error')
    print(e.status_code)
    for msg in iter(e):
        print(msg)

except TwitterConnectionError as e:
    print('Connection error')
    print(e)

except Exception as e:
    print('Exception')
    print(e)
# Out:
# {'profile_image_url': 'https://pbs.twimg.com/profile_images/1388118665187430410/hgDuUhCX_normal.jpg', 'id': '1388118411130122245', 'verified': False, 'username': 'MDZ91114164', 'name': 'MDZ'}
# {'profile_image_url': 'https://pbs.twimg.com/profile_images/1352685707865829376/7xHJwOS0_normal.jpg', 'id': '156229652', 'verified': True, 'username': 'jonmosesvocals', 'location': 'York, England', 'name': 'Jon Moses'}
# {'profile_image_url': 'https://pbs.twimg.com/profile_images/1364263812258529284/KebmjFpL_normal.jpg', 'id': '1024517222', 'verified': False, 'username': '__keepachris__', 'location': 'Liverpool, England', 'name': '•●ツ ᴋᴇᴇᴘᴀᴄʜʀɪs ツ ●•'}
# {'profile_image_url': 'https://pbs.twimg.com/profile_images/1173297293145124867/ERsLQD3N_normal.png', 'id': '1172376123054813186', 'verified': False, 'username': 'FadeToDarkMusic', 'location': 'New York, NY', 'name': 'Fade To Dark'}
# ...
